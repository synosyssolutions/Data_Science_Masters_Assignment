# %%
'''Q1. Explain why we have to use the Exception class while creating a Custom Exception.'''
# Out:
# 'Q1. Explain why we have to use the Exception class while creating a Custom Exception.'

# %%
'''Exception class is the base class for all the exception, it has all the exception related implementation in it and in our custome exception class we can override those values to throw our desired exception '''
# Out:
# 'Exception class is the base class for all the exception, it has all the exception related implementation in it and in our custome exception class we can override those values to throw our desired exception '

# %%
'''Q2. Write a python program to print Python Exception Hierarchy.'''
# Out:
# 'Q2. Write a python program to print Python Exception Hierarchy.'

# %%
import inspect

def treeClass(cls,ind = 0):
    print('-' * ind,cls.__name__)
    
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
    print('Hierarchy for built-in Exception : ')
    
inspect.getclasstree(inspect.getmro(BaseException)) 
treeClass(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# Hierarchy for built-in Exception :
# --------- MultipartConversionError
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ------ StopAsyncIteration
# Hierarchy for built-in Exception :
# ------ StopIteration
# Hierarchy for built-in Exception :
# ------ ImportError
# --------- ModuleNotFoundError
# Hierarchy for built-in Exception :
# --------- ZipImportError
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# Hierarchy for built-in Exception :
# ------------ ConnectionAbortedError
# Hierarchy for built-in Exception :
# ------------ ConnectionRefusedError
# Hierarchy for built-in Exception :
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ...

# %%
'''Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.'''
# Out:
# 'Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.'

# %%
import inspect

def treeClass(cls,ind = 0):
    print('-' * ind,cls.__name__)
    
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
    print('Hierarchy for built-in Exception : ')
    
inspect.getclasstree(inspect.getmro(ArithmeticError)) 
treeClass(ArithmeticError)
# Out:
#  ArithmeticError
# --- FloatingPointError
# Hierarchy for built-in Exception :
# --- OverflowError
# Hierarchy for built-in Exception :
# --- ZeroDivisionError
# ------ DivisionByZero
# Hierarchy for built-in Exception :
# ------ DivisionUndefined
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# --- DecimalException
# ------ Clamped
# Hierarchy for built-in Exception :
# ------ Rounded
# --------- Underflow
# Hierarchy for built-in Exception :
# --------- Overflow
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ------ Inexact
# --------- Underflow
# Hierarchy for built-in Exception :
# --------- Overflow
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ------ Subnormal
# --------- Underflow
# Hierarchy for built-in Exception :
# Hierarchy for built-in Exception :
# ------ DivisionByZero
# Hierarchy for built-in Exception :
# ------ FloatOperation
# Hierarchy for built-in Exception :
# ...

# %%
# example FloatingPointError ==> overflowerror

print('3.0 to the power of 256 =', 3.0**256)
print('3.0 to the power of 512 = ', 3.0**512)
print('3.0 to the power of 1024 = ', 3.0**1024)
# Out:
# 3.0 to the power of 256 = 1.3900845237714473e+122
# 3.0 to the power of 512 =  1.9323349832288915e+244
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[7], line 5
#       3 print('3.0 to the power of 256 =', 3.0**256)
#       4 print('3.0 to the power of 512 = ', 3.0**512)
# ----> 5 print('3.0 to the power of 1024 = ', 3.0**1024)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
print('3.0 to the power of 256 =', 3.0**256)
print('3.0 to the power of 512 = ', 3.0**512)
try:
    print('3.0 to the power of 1024 = ', 3.0**1024)
except Exception as e:
    print(e)
# Out:
# 3.0 to the power of 256 = 1.3900845237714473e+122
# 3.0 to the power of 512 =  1.9323349832288915e+244
# (34, 'Numerical result out of range')

# %%
# example ZerDivisionError

try:
    10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
'''Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.'''
# Out:
# 'Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.'

# %%
'''LookupError Exception is the Base class for errors raised when something can’t be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError'''
# Out:
# 'LookupError Exception is the Base class for errors raised when something can’t be found. The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: IndexError, KeyError'

# %%
# An IndexError is raised when a sequence reference is out of range.

l = [10,20,30]
try:
    a = l[3]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
# A Python KeyError exception is what is raised when you try to access a key that isn’t in a dictionary (dict).

emp_dict = {'name':'Piyush','age':23,'eamil':'piyush@gmail.com'}
try:
    a = emp_dict['mobile']
except KeyError as e:
    print('No such key present in emp_dict ',e)
# Out:
# No such key present in emp_dict  'mobile'

# %%
'''Q5. Explain ImportError. What is ModuleNotFoundError?'''
# Out:
# 'Q5. Explain ImportError. What is ModuleNotFoundError?'

# %%
'''ModuleNotFoundError is a kind of ImportError. It's raised specifically when the module cannot be found at all. Other problems can occur after the file is found, but during the actual process of loading the file or defining the function: those would raise ImportError.'''
# Out:
# "ModuleNotFoundError is a kind of ImportError. It's raised specifically when the module cannot be found at all. Other problems can occur after the file is found, but during the actual process of loading the file or defining the function: those would raise ImportError."

# %%
'''Q6. List down some best practices for exception handling in python.'''
# Out:
# 'Q6. List down some best practices for exception handling in python.'

# %%
# use specific exception instead of general exception
# use logging for error
# print always proper message in case of exception 
# avoid multiple exception handling
# document all error and cleanup all resources
